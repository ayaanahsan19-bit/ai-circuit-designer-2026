# %%
# Test Streamlit installation
import streamlit as st
print(f"Streamlit version: {st.__version__}")

# Test AI import
from src.models.simple_circuit_ai import SimpleCircuitAI
ai = SimpleCircuitAI()
print("✅ AI and Streamlit ready for web UI!")
